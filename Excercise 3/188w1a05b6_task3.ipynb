# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha199-ops/DataAnalyticsLab/blob/master/Excercise%203/188w1a05b6_task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn. datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
data=load_iris()
print('Classes to predict:',data.target_names)
# Out:
# Classes to predict: ['setosa' 'versicolor' 'virginica']

# %%
X=data.data
y=data.target
print("Number of records in dataset:",X.shape[0])
print(X[:4])
# Out:
# Number of records in dataset: 150
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]]

# %%
X_train,X_test,y_train, y_test=train_test_split(X,y,random_state=22, test_size=0.45)

# %%
clf=DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy score on train data',accuracy_score
      (y_true=y_train,y_pred=clf.predict(X_train)))
print('Accuracy score on test data',accuracy_score
      (y_true=y_test,y_pred=y_pred))
# Out:
# Accuracy score on train data 1.0
# Accuracy score on test data 0.9411764705882353

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (20,20))
plot_tree(clf,filled=True)
plt.show()

# %% [markdown]
# # New Section

# %% [markdown]
# POST LAB TASK

# %%
df = pd.read_csv('TESTDATA.CSV')
df.replace(' ','',regex=True)
df['Golf Play'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['Weather']= label_encoder.fit_transform(df['Weather'])
df['Temperature']= label_encoder.fit_transform(df['Temperature'])
df['Humidity']= label_encoder.fit_transform(df['Humidity'])
df['Wind']= label_encoder.fit_transform(df['Wind'])
df['Golf Play']= label_encoder.fit_transform(df['Golf Play'])

# %%
df
# Out:
#     Weather  Temperature  Humidity  Wind  Golf Play
# 0         1            1         0     1          0
# 1         1            1         0     0          0
# 2         0            1         0     1          1
# 3         2            2         0     1          1
# 4         2            0         1     2          1
# 5         2            0         1     0          0
# 6         0            0         1     0          1
# 7         1            2         0     1          0
# 8         1            0         1     1          1
# 9         2            2         1     1          1
# 10        1            2         1     0          1
# 11        0            2         0     0          1
# 12        0            1         1     1          1
# 13        2            2         0     0          0

# %%
X= df.iloc[:,:4]
Y= df.iloc[:,4]
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: Golf Play, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train, Y_test=train_test_split(X,Y,random_state=15, test_size=0.25)

# %%
clf=DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy score on train data',accuracy_score(y_true = Y_train,y_pred=clf.predict(X_train)))
print('Accuracy score on test data',accuracy_score(y_true= Y_test, y_pred= y_pred))
# Out:
# Accuracy score on train data 1.0
# Accuracy score on test data 0.75

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from matplotlib import pyplot as plt

plt.figure(figsize = (10,10))
plot_tree(clf,filled=True)
plt.show()
